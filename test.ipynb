# %%
from matplotlib import pyplot as plt
import numpy as np
import math
# %matplotlib inline
x=np.arange(0, math.pi*4, 0.05)
y=np.sin(x)
fig=plt.figure()
ax = fig.add_subplot(111)
ax.plot(x,y)

# %%
a = 3.0
print(a)
# Out:
# 3.0
